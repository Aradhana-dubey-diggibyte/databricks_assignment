# %%
# %run ../dim_full_load/Configuration

# %%
dim_table_map = {
    "dbo.DIM_CUSTOMER": "learning_lab_catalog.bronze.dim_customer",
    "dbo.DIM_BRANCH": "learning_lab_catalog.bronze.dim_branch",
    "dbo.DIM_TRANSACTION_TYPE": "learning_lab_catalog.bronze.dim_transaction_type",
    "dbo.DIM_TRANSACTION_STATUS": "learning_lab_catalog.bronze.dim_transaction_status"
}

# %%
for source_table, target_table in dim_table_map.items():

    df = spark.read.jdbc(
        url=jdbc_url,                 
        table=source_table,
        properties=jdbc_properties     
    )

    df.write \
        .format("delta") \
        .mode("overwrite") \
        .option("overwriteSchema", "true") \
        .saveAsTable(target_table)

    print(f"Loaded {source_table} into {target_table}")
