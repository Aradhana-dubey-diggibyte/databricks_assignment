# %%
# %sql
CREATE TABLE IF NOT EXISTS learning_lab_catalog.bronze.dim_customer (
    Customer_ID INT,
    Customer_Name STRING,
    Address STRING,
    Contact_Info STRING
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS learning_lab_catalog.bronze.dim_branch (
    Branch_ID INT,
    Branch_Name STRING,
    Location STRING,
    Region STRING
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS learning_lab_catalog.bronze.dim_transaction_type (
    Type_ID INT,
    Transaction_Type STRING
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS learning_lab_catalog.bronze.dim_transaction_status (
    Status_ID INT,
    Status_Description STRING,
    Detailed_Description STRING
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS learning_lab_catalog.bronze.dim_date (
    Date_ID INT,
    Transaction_Date DATE,
    Day INT,
    Month STRING,
    Year INT
)
USING DELTA;
