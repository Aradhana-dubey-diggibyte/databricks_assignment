# %%
# connection properties
jdbc_url = "jdbc:sqlserver://lfsql16611.database.windows.net:1433;database=lfdemo"
connection_props = {
    "user": "sqladminuser",
    "password": "StrongP@ssw0rd!",
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}
 
# Query system catalog to get table names
query = "(SELECT TABLE_CATALOG, TABLE_SCHEMA, TABLE_NAME FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_TYPE='BASE TABLE') AS tbl"
 
# Read into Spark DataFrame
df = spark.read.jdbc(url=jdbc_url, table=query, properties=connection_props)

try:
  df.show()
except Exception as e:
  print(e)
 
#display(df)

# %%
jdbc_url = "jdbc:sqlserver://lfsql16611.database.windows.net:1433;database=lfdemo"

schema_query = """
(
    SELECT 
        COLUMN_NAME, 
        DATA_TYPE, 
        CHARACTER_MAXIMUM_LENGTH, 
        IS_NULLABLE 
    FROM INFORMATION_SCHEMA.COLUMNS 
    WHERE TABLE_SCHEMA = 'dbo' AND TABLE_NAME = 'FACT_TRANSACTION'
) AS schema_info
"""

fact_transaction_schema_df = spark.read.jdbc(
    url=jdbc_url,
    table=schema_query,
    properties={
        "user": "sqladminuser",
        "password": "StrongP@ssw0rd!",
        "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
    }
)

display(fact_transaction_schema_df)

# %%
df1 = fact_transaction_df
df2 = spark.sql("SELECT * FROM learning_lab_catalog.silver.fact_transaction")

df1.display()
df2.display()

# %%
# %sql
select * from learning_lab_catalog.bronze.dim_branch

# %%
# %sql
select* from learning_lab_catalog.bronze.dim_customer
