# %%
# %sql
USE CATALOG learning_lab_catalog;
USE SCHEMA lakebridge_recon;

SHOW TABLES;

# %%
# %sql
SELECT * FROM learning_lab_catalog.lakebridge_recon.main
ORDER BY  recon_id DESC
LIMIT 5;

# %%
# %sql
SELECT * FROM learning_lab_catalog.lakebridge_recon.details
ORDER BY recon_table_id  DESC 
LIMIT 10;
